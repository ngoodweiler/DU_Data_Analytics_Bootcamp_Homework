# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
temps = [39,42,51,62,72,82,86,84,77,65,55,44]
temps
# Out:
# [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]

# %%
temps_c = [(x-32)*5/9 for x in temps]
temps_c
# Out:
# [3.888888888888889,
#  5.555555555555555,
#  10.555555555555555,
#  16.666666666666668,
#  22.22222222222222,
#  27.77777777777778,
#  30.0,
#  28.88888888888889,
#  25.0,
#  18.333333333333332,
#  12.777777777777779,
#  6.666666666666667]

# %%
x_axis = np.arange(1,13,1)
temps, = plt.plot(x_axis,temps,label='Fahrenheit',marker='s',color='b')
temps_c = plt.plot(x_axis,temps_c,label='Celsius',marker='+',color='r')
plt.xlabel('Month')
plt.ylabel('Temperature')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
