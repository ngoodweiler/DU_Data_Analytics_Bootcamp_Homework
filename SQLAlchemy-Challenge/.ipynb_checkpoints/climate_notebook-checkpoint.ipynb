# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# importing inspect to get the columns in the two tables
from sqlalchemy import inspect
inspector = inspect(engine)

# %%
# columns in measurement table
m_columns = inspector.get_columns('measurement')
for c in m_columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# columns in station table
s_columns = inspector.get_columns('station')
for c in s_columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
# Calculate the date 1 year ago from the last data point in the database
# From analyzing the csv file, the last date entry is 2017-08-23, therefor we want start date to be >2016-08-23
# can also find this by doing session.query(Measurement.date).order_by(Measurement.date.desc()) for the same result
# Perform a query to retrieve the data and precipitation scores
measurements=session.query(Measurement.date,Measurement.station,Measurement.prcp).\
    filter(Measurement.date > "2016-08-23").all()
measurements_date = [result[0] for result in measurements]
measurements_station = [result[1] for result in measurements]
measurements_prcp = [result[2] for result in measurements]
measurements_date
# Out:
# ['2016-08-24',
#  '2016-08-25',
#  '2016-08-26',
#  '2016-08-27',
#  '2016-08-28',
#  '2016-08-29',
#  '2016-08-30',
#  '2016-08-31',
#  '2016-09-01',
#  '2016-09-02',
#  '2016-09-03',
#  '2016-09-04',
#  '2016-09-05',
#  '2016-09-06',
#  '2016-09-07',
#  '2016-09-08',
#  '2016-09-09',
#  '2016-09-10',
#  '2016-09-11',
#  '2016-09-12',
#  '2016-09-13',
#  '2016-09-14',
#  '2016-09-15',
#  '2016-09-16',
#  '2016-09-17',
#  '2016-09-18',
#  '2016-09-19',
#  '2016-09-20',
#  '2016-09-21',
#  '2016-09-22',
#  '2016-09-23',
#  '2016-09-24',
#  '2016-09-25',
#  '2016-09-26',
#  '2016-09-27',
#  '2016-09-28',
#  '2016-09-29',
#  '2016-09-30',
#  '2016-10-01',
#  '2016-10-02',
#  '2016-10-03',
#  '2016-10-04',
#  '2016-10-05',
#  '2016-10-06',
#  '2016-10-07',
#  '2016-10-08',
#  '2016-10-09',
#  '2016-10-10',
#  '2016-10-11',
#  '2016-10-12',
#  '2016-10-13',
#  '2016-10-14',
#  '2016-10-15',
#  '2016-10-16',
#  '2016-10-17',
#  '2016-10-18',
#  '2016-10-19',
#  '2016-10-20',
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
precipitation = {'Date':measurements_date,'Station':measurements_station,'Precipitation':measurements_prcp}
# Sort the dataframe by date
precipitation = pd.DataFrame(precipitation).sort_values(['Date','Precipitation']).dropna()
precipitation = precipitation.set_index('Date')
precipitation
# Out:
#                 Station  Precipitation
# Date
# 2016-08-24  USC00519397           0.08
# 2016-08-24  USC00519523           1.22
# 2016-08-24  USC00516128           1.45
# 2016-08-24  USC00513117           2.15
# 2016-08-24  USC00519281           2.15
# ...                 ...            ...
# 2017-08-22  USC00516128           0.50
# 2017-08-23  USC00519397           0.00
# 2017-08-23  USC00514830           0.00
# 2017-08-23  USC00519523           0.08
# 2017-08-23  USC00516128           0.45
#
# [2015 rows x 2 columns]

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import matplotlib
prcp_bar = precipitation[precipitation.Precipitation !=0]
fig, ax = plt.subplots(figsize=(20,15))
ax.bar(prcp_bar.index,prcp_bar['Precipitation'],width=4,label='Precipitation')
plt.xlabel('Date')
plt.ylabel('Precipitation (in)')
ax.xaxis.set_major_locator(MultipleLocator(70))
matplotlib.rc('font', size=24)
matplotlib.rc('axes', titlesize=24)
ax.legend(loc='upper center')
plt.savefig('Images/precipitation_by_date.png')
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
precipitation.describe()
# Out:
#        Precipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# Design a query to show how many stations are available in this dataset?
session.query(func.count(Station.id)).all()
# Out:
# [(9)]

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
station_counts = session.query(Measurement.station,func.count(Measurement.station)).group_by('station').order_by(func.count(Measurement.station).desc()).all()
station_counts
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
station_info = session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.sum(Measurement.tobs)/func.count(Measurement.tobs)).filter(Measurement.station == station_counts[0][0]).all()
station_info
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
station_temp = session.query(Measurement.date,Measurement.tobs).filter(Measurement.date > "2016-08-23").\
    filter(Measurement.station == station_counts[0][0]).all()
station_temp_date = [result[0] for result in station_temp]
station_temp_temp = [result[1] for result in station_temp]
station_temp = {'Date':station_temp_date,'Temperature':station_temp_temp}
station_temp = pd.DataFrame(station_temp).sort_values('Date').dropna()
station_temp = station_temp.set_index('Date')
station_temp
# Out:
#             Temperature
# Date
# 2016-08-24         77.0
# 2016-08-25         80.0
# 2016-08-26         80.0
# 2016-08-27         75.0
# 2016-08-28         73.0
# ...                 ...
# 2017-08-14         77.0
# 2017-08-15         77.0
# 2017-08-16         76.0
# 2017-08-17         76.0
# 2017-08-18         79.0
#
# [351 rows x 1 columns]

# %%
# plt.hist(station_temp['Temperature'])
# plt.xlabel('Temperature (F)')
# plt.ylabel('Frequency)')
# plt.title('Histogram of Temperature for station USC00519281, 8/24/2016 - 8/23/2017')

fig, ax = plt.subplots(figsize=(20,15))
ax.hist(station_temp['Temperature'],label='Temperature',bins=12)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
ax.xaxis.set_major_locator(MultipleLocator(5))
matplotlib.rc('font', size=24)
matplotlib.rc('axes', titlesize=24)
ax.legend(loc='upper center')
plt.title('Histogram of Temperature for station USC00519281, 8/24/2016 - 8/23/2017')
plt.savefig('Images/temp_hist.png')
plt.show()

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
# Trip date = 4/1 - 4/9, so using data from 2017-04-01 to 2017-04-09
station_calcs = calc_temps('2017-04-01', '2017-04-09')
station_calcs
# Out:
# [(67.0, 74.53571428571429, 80.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
yerror = station_calcs[0][2] - station_calcs[0][0]
bar_x = station_calcs[0][1]
fig, ax = plt.subplots(figsize=(5,15))
ax.bar(1,bar_x,width=1,yerr=yerror,color='red',alpha=0.4)
plt.ylabel('Temperature (F)')
matplotlib.rc('font', size=24)
matplotlib.rc('axes', titlesize=24)
plt.title('Trip Avg Temp')
plt.ylim(0,100)
plt.tick_params(
    axis='x',
    which='both',
    bottom=False,
    top=False,
    labelbottom=False)
plt.grid(b=None,which='major',axis='x')
plt.savefig('Images/temp_bar.png')
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
prcp_station = session.query(Measurement.station,Station.name,Station.latitude,Station.longitude,Station.elevation,Measurement.prcp,Measurement.date).\
    filter(Measurement.date >='2017-04-01').filter(Measurement.date <='2017-04-09').all()
prcp_station_id = [result[0] for result in prcp_station]
prcp_station_name = [result[1] for result in prcp_station]
prcp_station_lat = [result[2] for result in prcp_station]
prcp_station_lng = [result[3] for result in prcp_station]
prcp_station_ele = [result[4] for result in prcp_station]
prcp_station_prcp = [result[5] for result in prcp_station]
prcp_station_date = [result[6] for result in prcp_station]
prcp_station = {'id':prcp_station_id,'Name':prcp_station_name,'Latitude':prcp_station_lat,
               'Longitude':prcp_station_lng,'Elevation':prcp_station_ele,
               'Precipitation':prcp_station_prcp,'Date':prcp_station_date}
prcp_station = pd.DataFrame(prcp_station).sort_values('Precipitation',ascending=False)
prcp_station
# Out:
#               id                                Name  Latitude  Longitude  \
# 469  USC00516128                KANEOHE 838.1, HI US  21.42340 -157.80150
# 468  USC00516128                WAIKIKI 717.2, HI US  21.27160 -157.81680
# 475  USC00516128   HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# 474  USC00516128                 WAIHEE 837.5, HI US  21.45167 -157.84889
# 473  USC00516128  WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# ..           ...                                 ...       ...        ...
# 490  USC00516128          UPPER WAHIAWA 874.3, HI US  21.49920 -158.01110
# 491  USC00516128  WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# 492  USC00516128                 WAIHEE 837.5, HI US  21.45167 -157.84889
# 493  USC00516128   HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# 494  USC00516128        MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
#
#      Elevation  Precipitation        Date
# ...

# %%
# Precipitation DF
trip_prcp = prcp_station.groupby('id').sum()
trip_prcp = trip_prcp.drop(columns=['Latitude','Longitude','Elevation'])
trip_prcp
# Out:
#              Precipitation
# id
# USC00513117           1.44
# USC00514830           1.44
# USC00516128           8.10
# USC00517948           0.00
# USC00519281           6.48
# USC00519397           0.00
# USC00519523           0.00

# %%
# Station info
trip_stations = session.query(Station.station,Station.name,Station.latitude,Station.longitude,Station.elevation).all()
trip_stations = pd.DataFrame(trip_stations)
trip_stations = trip_stations.rename(columns={'station':'id','name':'Station Name','latitude':'Latitude','longitude':'Longitude','elevation':'Elevation'})
trip_stations = trip_stations.set_index('id')
trip_stations
# Out:
#                                        Station Name  Latitude  Longitude  \
# id
# USC00519397                    WAIKIKI 717.2, HI US  21.27160 -157.81680
# USC00513117                    KANEOHE 838.1, HI US  21.42340 -157.80150
# USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740
# USC00517948                       PEARL CITY, HI US  21.39340 -157.97510
# USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920 -158.01110
# USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# USC00519281                     WAIHEE 837.5, HI US  21.45167 -157.84889
# USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
#
#              Elevation
# id
# USC00519397        3.0
# USC00513117       14.6
# USC00514830        7.0
# USC00517948       11.9
# USC00518838      306.6
# USC00519523       19.5
# USC00519281       32.9
# USC00511918        0.9
# ...

# %%
# Join and sorting
trip_df = trip_stations.join(trip_prcp,on='id',how='left')
trip_df = trip_df.rename(columns={'Precipitation':'Total Precipitation'})
trip_df = trip_df.sort_values('Total Precipitation',ascending=False).dropna()
trip_df
# Out:
#                                        Station Name  Latitude  Longitude  \
# id
# USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
# USC00519281                     WAIHEE 837.5, HI US  21.45167 -157.84889
# USC00513117                    KANEOHE 838.1, HI US  21.42340 -157.80150
# USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740
# USC00519397                    WAIKIKI 717.2, HI US  21.27160 -157.81680
# USC00517948                       PEARL CITY, HI US  21.39340 -157.97510
# USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
#
#              Elevation  Total Precipitation
# id
# USC00516128      152.4                 8.10
# USC00519281       32.9                 6.48
# USC00513117       14.6                 1.44
# USC00514830        7.0                 1.44
# USC00519397        3.0                 0.00
# USC00517948       11.9                 0.00
# USC00519523       19.5                 0.00

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
normals =[]
# Set the start and end date of the trip
start_date = dt.datetime(2020,4,8)
end_date = dt.datetime(2020,4,16)
# Use the start and end date to create a range of dates
date_range = end_date - start_date
# Stip off the year and save a list of %m-%d strings
days = [8,9,10,11,12,13,14,15,16]
month = [4,4,4,4,4,4,4,4,4]
normals['Day'] = days
normals['Month'] = month
normals = {'Day':days,'Month':month}
normals
# Loop through the list of %m-%d strings and calculate the normals for each date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-7dbb16f676dc> in <module>
#      10 days = [8,9,10,11,12,13,14,15,16]
#      11 month = [4,4,4,4,4,4,4,4,4]
# ---> 12 normals['Day'] = days
#      13 normals['Month'] = month
#      14 normals = {'Day':days,'Month':month}
#
# TypeError: list indices must be integers or slices, not str

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
normals = normals.append()
# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date
# Out:
# [(62.0, 69.15384615384616, 77.0),
#  (60.0, 69.39622641509433, 77.0),
#  (62.0, 68.9090909090909, 77.0),
#  (58.0, 70.0, 76.0),
#  (56.0, 67.96428571428571, 76.0),
#  (61.0, 68.96491228070175, 76.0),
#  (57.0, 68.54385964912281, 76.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
# Out:
#             tmin       tavg  tmax
# date
# 2018-01-01  62.0  69.153846  77.0
# 2018-01-02  60.0  69.396226  77.0
# 2018-01-03  62.0  68.909091  77.0
# 2018-01-04  58.0  70.000000  76.0
# 2018-01-05  56.0  67.964286  76.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
# Out:
# <img src="data:image/png;base64,..." width="640">
