# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %%
cities_dict = {'City':cities}
cities_df = pd.DataFrame(cities_dict)
cities_df.head()
# Out:
#            City
# 0        hobart
# 1  constitucion
# 2     carnarvon
# 3  sentyabrskiy
# 4       satitoa

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Open weather
url = "http://api.openweathermap.org/data/2.5/weather?"

# Partial query url
query_url = f"{url}appid={weather_api_key}&units=imperial&q="

# %%
# Test response to see what the data looks like
city_test = 'Seattle'
response = requests.get(query_url+city_test).json()
response
# Out:
# {'coord': {'lon': -122.33, 'lat': 47.61},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 44.46,
#   'feels_like': 41.27,
#   'temp_min': 42.01,
#   'temp_max': 46.99,
#   'pressure': 1013,
#   'humidity': 100},
#  'visibility': 16093,
#  'wind': {'speed': 3.36, 'deg': 330},
#  'rain': {'1h': 0.66},
#  'clouds': {'all': 90},
#  'dt': 1579965181,
#  'sys': {'type': 1,
#   'id': 5692,
#   'country': 'US',
#   'sunrise': 1579967071,
#   'sunset': 1580000300},
#  'timezone': -28800,
#  'id': 5809844,
#  'name': 'Seattle',
#  'cod': 200}

# %%
# test data pulling
# test_clouds = response['clouds']['all']
# test_country = response['sys']['country']
# test_date = response['dt']
# test_humidity = response['main']['humidity']
# test_lat = response['coord']['lat']
# test_lng = response['coord']['lon']
# test_temp = response['main']['temp_max']
# test_wind = response['wind']['speed']
# print(f'clouds = {test_clouds}, country = {test_country}, date = {test_date}, humidity = {test_humidity}, latitude = {test_lat}, longitude = {test_lng}, temp = {test_temp}, wind = {test_wind}')

# %%
# Require City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed
# City is already available
weather_city = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind = []
call_count = 0
city_count = 0
set_count = 1
#Loop through cities and add appropriate data to lists
#Incorporate 60 second timer every 50 cities to ensure API doesnt get maxed out
print('Begin data retrieval')
print('-------------------------')
for index, row in cities_df.iterrows():
    city = row['City']
    response = requests.get(query_url+city).json()
    city_count = city_count + 1
    try:
        print(f'Processing record {city_count} of Set {set_count} | {city}')
        weather_city.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
    except (KeyError, IndexError):
        print('-------------------------')
        print("City not found, skipping...")
    call_count = call_count + 1
    print('-------------------------')
    if call_count == 50:
        print("50 results found, waiting for API to refresh")
        time.sleep(60)
        set_count = set_count + 1
        call_count = 0
        city_count = 0
print('Data retrieval complete')
print('-------------------------')
# Out:
# Begin data retrieval
# -------------------------
# Processing record 1 of Set 1 | hobart
# -------------------------
# Processing record 2 of Set 1 | constitucion
# -------------------------
# Processing record 3 of Set 1 | carnarvon
# -------------------------
# Processing record 4 of Set 1 | sentyabrskiy
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 5 of Set 1 | satitoa
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 6 of Set 1 | aklavik
# -------------------------
# Processing record 7 of Set 1 | nelson bay
# -------------------------
# Processing record 8 of Set 1 | hasaki
# -------------------------
# Processing record 9 of Set 1 | rikitea
# -------------------------
# Processing record 10 of Set 1 | maningrida
# -------------------------
# Processing record 11 of Set 1 | arraial do cabo
# -------------------------
# Processing record 12 of Set 1 | lavrentiya
# -------------------------
# Processing record 13 of Set 1 | barrow
# -------------------------
# Processing record 14 of Set 1 | fortuna
# -------------------------
# Processing record 15 of Set 1 | hohhot
# -------------------------
# Processing record 16 of Set 1 | lira
# -------------------------
# Processing record 17 of Set 1 | nikolskoye
# -------------------------
# Processing record 18 of Set 1 | punta arenas
# -------------------------
# Processing record 19 of Set 1 | amderma
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 20 of Set 1 | new norfolk
# -------------------------
# Processing record 21 of Set 1 | xiuyan
# -------------------------
# Processing record 22 of Set 1 | dikson
# -------------------------
# Processing record 23 of Set 1 | ribeira grande
# -------------------------
# Processing record 24 of Set 1 | jinchang
# -------------------------
# Processing record 25 of Set 1 | ushuaia
# -------------------------
# Processing record 26 of Set 1 | nizhneyansk
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 27 of Set 1 | auki
# -------------------------
# Processing record 28 of Set 1 | gorno-chuyskiy
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 29 of Set 1 | gao
# -------------------------
# Processing record 30 of Set 1 | barentsburg
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 31 of Set 1 | vaini
# -------------------------
# Processing record 32 of Set 1 | bisho
# -------------------------
# Processing record 33 of Set 1 | grindavik
# -------------------------
# Processing record 34 of Set 1 | leningradskiy
# -------------------------
# Processing record 35 of Set 1 | sao joao da barra
# -------------------------
# Processing record 36 of Set 1 | asau
# -------------------------
# Processing record 37 of Set 1 | derzhavinsk
# -------------------------
# Processing record 38 of Set 1 | esperance
# -------------------------
# Processing record 39 of Set 1 | yulara
# -------------------------
# Processing record 40 of Set 1 | jamestown
# -------------------------
# Processing record 41 of Set 1 | kapaa
# -------------------------
# Processing record 42 of Set 1 | ahipara
# -------------------------
# Processing record 43 of Set 1 | mataura
# -------------------------
# Processing record 44 of Set 1 | khatanga
# -------------------------
# Processing record 45 of Set 1 | kavieng
# -------------------------
# Processing record 46 of Set 1 | chicama
# -------------------------
# Processing record 47 of Set 1 | college
# -------------------------
# Processing record 48 of Set 1 | touros
# -------------------------
# Processing record 49 of Set 1 | qaanaaq
# -------------------------
# Processing record 50 of Set 1 | bodden town
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 2 | albany
# -------------------------
# Processing record 2 of Set 2 | lompoc
# -------------------------
# Processing record 3 of Set 2 | guaymas
# -------------------------
# Processing record 4 of Set 2 | ponta do sol
# -------------------------
# Processing record 5 of Set 2 | puerto ayora
# -------------------------
# Processing record 6 of Set 2 | strezhevoy
# -------------------------
# Processing record 7 of Set 2 | verkhoyansk
# -------------------------
# Processing record 8 of Set 2 | umzimvubu
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 9 of Set 2 | ararangua
# -------------------------
# Processing record 10 of Set 2 | kahului
# -------------------------
# Processing record 11 of Set 2 | tual
# -------------------------
# Processing record 12 of Set 2 | manzhouli
# -------------------------
# Processing record 13 of Set 2 | nador
# -------------------------
# Processing record 14 of Set 2 | bani
# -------------------------
# Processing record 15 of Set 2 | castro
# -------------------------
# Processing record 16 of Set 2 | port alfred
# -------------------------
# Processing record 17 of Set 2 | hilo
# -------------------------
# Processing record 18 of Set 2 | miles city
# -------------------------
# Processing record 19 of Set 2 | tonaya
# -------------------------
# Processing record 20 of Set 2 | butaritari
# -------------------------
# Processing record 21 of Set 2 | grand island
# -------------------------
# Processing record 22 of Set 2 | tuatapere
# -------------------------
# Processing record 23 of Set 2 | bredasdorp
# -------------------------
# Processing record 24 of Set 2 | tha mai
# -------------------------
# Processing record 25 of Set 2 | bethel
# -------------------------
# Processing record 26 of Set 2 | east london
# -------------------------
# Processing record 27 of Set 2 | tepulco
# -------------------------
# Processing record 28 of Set 2 | longyearbyen
# -------------------------
# Processing record 29 of Set 2 | husavik
# -------------------------
# Processing record 30 of Set 2 | avarua
# -------------------------
# Processing record 31 of Set 2 | saint-philippe
# -------------------------
# Processing record 32 of Set 2 | mar del plata
# -------------------------
# Processing record 33 of Set 2 | tripoli
# -------------------------
# Processing record 34 of Set 2 | bluff
# -------------------------
# Processing record 35 of Set 2 | balimo
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 36 of Set 2 | simdega
# -------------------------
# Processing record 37 of Set 2 | naze
# -------------------------
# Processing record 38 of Set 2 | independence
# -------------------------
# Processing record 39 of Set 2 | thompson
# -------------------------
# Processing record 40 of Set 2 | busselton
# -------------------------
# Processing record 41 of Set 2 | bilibino
# -------------------------
# Processing record 42 of Set 2 | torbay
# -------------------------
# Processing record 43 of Set 2 | norman wells
# -------------------------
# Processing record 44 of Set 2 | puerto quijarro
# -------------------------
# Processing record 45 of Set 2 | karratha
# -------------------------
# Processing record 46 of Set 2 | tabou
# -------------------------
# Processing record 47 of Set 2 | illoqqortoormiut
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 48 of Set 2 | kadykchan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 49 of Set 2 | altmunster
# -------------------------
# Processing record 50 of Set 2 | taolanaro
# -------------------------
# City not found, skipping...
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 3 | salalah
# -------------------------
# Processing record 2 of Set 3 | atuona
# -------------------------
# Processing record 3 of Set 3 | batie
# -------------------------
# Processing record 4 of Set 3 | cockburn harbour
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 5 of Set 3 | batagay-alyta
# -------------------------
# Processing record 6 of Set 3 | lipari
# -------------------------
# Processing record 7 of Set 3 | franklin
# -------------------------
# Processing record 8 of Set 3 | maceio
# -------------------------
# Processing record 9 of Set 3 | krasnyy yar
# -------------------------
# Processing record 10 of Set 3 | polovinnoye
# -------------------------
# Processing record 11 of Set 3 | crib point
# -------------------------
# Processing record 12 of Set 3 | kruisfontein
# -------------------------
# Processing record 13 of Set 3 | boralday
# -------------------------
# Processing record 14 of Set 3 | abiy adi
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 15 of Set 3 | vaitupu
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 16 of Set 3 | chuy
# -------------------------
# Processing record 17 of Set 3 | tautira
# -------------------------
# Processing record 18 of Set 3 | cape town
# -------------------------
# Processing record 19 of Set 3 | broome
# -------------------------
# Processing record 20 of Set 3 | batagay
# -------------------------
# Processing record 21 of Set 3 | boke
# -------------------------
# Processing record 22 of Set 3 | hami
# -------------------------
# Processing record 23 of Set 3 | hermanus
# -------------------------
# Processing record 24 of Set 3 | ilulissat
# -------------------------
# Processing record 25 of Set 3 | saldanha
# -------------------------
# Processing record 26 of Set 3 | bolungarvik
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 27 of Set 3 | ichchapuram
# -------------------------
# Processing record 28 of Set 3 | mutoko
# -------------------------
# Processing record 29 of Set 3 | manggar
# -------------------------
# Processing record 30 of Set 3 | chokurdakh
# -------------------------
# Processing record 31 of Set 3 | guaratinga
# -------------------------
# Processing record 32 of Set 3 | praia da vitoria
# -------------------------
# Processing record 33 of Set 3 | hofn
# -------------------------
# Processing record 34 of Set 3 | timbo
# -------------------------
# Processing record 35 of Set 3 | novyy urengoy
# -------------------------
# Processing record 36 of Set 3 | belushya guba
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 37 of Set 3 | yellowknife
# -------------------------
# Processing record 38 of Set 3 | urucara
# -------------------------
# Processing record 39 of Set 3 | santa rosa
# -------------------------
# Processing record 40 of Set 3 | qaqortoq
# -------------------------
# Processing record 41 of Set 3 | georgetown
# -------------------------
# Processing record 42 of Set 3 | hithadhoo
# -------------------------
# Processing record 43 of Set 3 | rosarito
# -------------------------
# Processing record 44 of Set 3 | camacha
# -------------------------
# Processing record 45 of Set 3 | kodiak
# -------------------------
# Processing record 46 of Set 3 | bengkulu
# -------------------------
# Processing record 47 of Set 3 | xam nua
# -------------------------
# Processing record 48 of Set 3 | yurimaguas
# -------------------------
# Processing record 49 of Set 3 | vila franca do campo
# -------------------------
# Processing record 50 of Set 3 | wajir
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 4 | fort nelson
# -------------------------
# Processing record 2 of Set 4 | san quintin
# -------------------------
# Processing record 3 of Set 4 | poltavka
# -------------------------
# Processing record 4 of Set 4 | altamira
# -------------------------
# Processing record 5 of Set 4 | bac lieu
# -------------------------
# Processing record 6 of Set 4 | ormara
# -------------------------
# Processing record 7 of Set 4 | provideniya
# -------------------------
# Processing record 8 of Set 4 | port hardy
# -------------------------
# Processing record 9 of Set 4 | arecibo
# -------------------------
# Processing record 10 of Set 4 | kanlagay
# -------------------------
# Processing record 11 of Set 4 | alihe
# -------------------------
# Processing record 12 of Set 4 | geraldton
# -------------------------
# Processing record 13 of Set 4 | samana
# -------------------------
# Processing record 14 of Set 4 | remanso
# -------------------------
# Processing record 15 of Set 4 | omaruru
# -------------------------
# Processing record 16 of Set 4 | borodino
# -------------------------
# Processing record 17 of Set 4 | saskylakh
# -------------------------
# Processing record 18 of Set 4 | azua
# -------------------------
# Processing record 19 of Set 4 | karamea
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 20 of Set 4 | tuktoyaktuk
# -------------------------
# Processing record 21 of Set 4 | marcona
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 22 of Set 4 | fuyu
# -------------------------
# Processing record 23 of Set 4 | port moresby
# -------------------------
# Processing record 24 of Set 4 | goderich
# -------------------------
# Processing record 25 of Set 4 | yengema
# -------------------------
# Processing record 26 of Set 4 | olafsvik
# -------------------------
# Processing record 27 of Set 4 | teya
# -------------------------
# Processing record 28 of Set 4 | tsihombe
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 29 of Set 4 | krasnoyarsk-66
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 30 of Set 4 | sao jose da coroa grande
# -------------------------
# Processing record 31 of Set 4 | mys shmidta
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 32 of Set 4 | riyadh
# -------------------------
# Processing record 33 of Set 4 | chernyanka
# -------------------------
# Processing record 34 of Set 4 | mergui
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 35 of Set 4 | trapani
# -------------------------
# Processing record 36 of Set 4 | ponta delgada
# -------------------------
# Processing record 37 of Set 4 | sakaiminato
# -------------------------
# Processing record 38 of Set 4 | lima
# -------------------------
# Processing record 39 of Set 4 | ambodifototra
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 40 of Set 4 | katsuura
# -------------------------
# Processing record 41 of Set 4 | kieta
# -------------------------
# Processing record 42 of Set 4 | cedar city
# -------------------------
# Processing record 43 of Set 4 | airai
# -------------------------
# Processing record 44 of Set 4 | changji
# -------------------------
# Processing record 45 of Set 4 | menongue
# -------------------------
# Processing record 46 of Set 4 | andenes
# -------------------------
# Processing record 47 of Set 4 | matara
# -------------------------
# Processing record 48 of Set 4 | am timan
# -------------------------
# Processing record 49 of Set 4 | haibowan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 50 of Set 4 | tumannyy
# -------------------------
# City not found, skipping...
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 5 | okhotsk
# -------------------------
# Processing record 2 of Set 5 | inongo
# -------------------------
# Processing record 3 of Set 5 | karoi
# -------------------------
# Processing record 4 of Set 5 | pisco
# -------------------------
# Processing record 5 of Set 5 | tasiilaq
# -------------------------
# Processing record 6 of Set 5 | port elizabeth
# -------------------------
# Processing record 7 of Set 5 | benton
# -------------------------
# Processing record 8 of Set 5 | prainha
# -------------------------
# Processing record 9 of Set 5 | kirovskiy
# -------------------------
# Processing record 10 of Set 5 | sitka
# -------------------------
# Processing record 11 of Set 5 | stokmarknes
# -------------------------
# Processing record 12 of Set 5 | kawana waters
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 13 of Set 5 | nanortalik
# -------------------------
# Processing record 14 of Set 5 | tura
# -------------------------
# Processing record 15 of Set 5 | kalamata
# -------------------------
# Processing record 16 of Set 5 | manzil jamil
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 17 of Set 5 | ozark
# -------------------------
# Processing record 18 of Set 5 | mehamn
# -------------------------
# Processing record 19 of Set 5 | upernavik
# -------------------------
# Processing record 20 of Set 5 | vila velha
# -------------------------
# Processing record 21 of Set 5 | nome
# -------------------------
# Processing record 22 of Set 5 | hulan ergi
# -------------------------
# Processing record 23 of Set 5 | brownsville
# -------------------------
# Processing record 24 of Set 5 | lebu
# -------------------------
# Processing record 25 of Set 5 | iralaya
# -------------------------
# Processing record 26 of Set 5 | samusu
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 27 of Set 5 | hihifo
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 28 of Set 5 | grand river south east
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 29 of Set 5 | djibo
# -------------------------
# Processing record 30 of Set 5 | khani
# -------------------------
# Processing record 31 of Set 5 | brae
# -------------------------
# Processing record 32 of Set 5 | rawson
# -------------------------
# Processing record 33 of Set 5 | tra vinh
# -------------------------
# Processing record 34 of Set 5 | coffs harbour
# -------------------------
# Processing record 35 of Set 5 | narsaq
# -------------------------
# Processing record 36 of Set 5 | luderitz
# -------------------------
# Processing record 37 of Set 5 | sorland
# -------------------------
# Processing record 38 of Set 5 | shingu
# -------------------------
# Processing record 39 of Set 5 | xining
# -------------------------
# Processing record 40 of Set 5 | ambilobe
# -------------------------
# Processing record 41 of Set 5 | dingle
# -------------------------
# Processing record 42 of Set 5 | acari
# -------------------------
# Processing record 43 of Set 5 | garowe
# -------------------------
# Processing record 44 of Set 5 | swidnica
# -------------------------
# Processing record 45 of Set 5 | takaka
# -------------------------
# Processing record 46 of Set 5 | puerto leguizamo
# -------------------------
# Processing record 47 of Set 5 | kapuskasing
# -------------------------
# Processing record 48 of Set 5 | parana
# -------------------------
# Processing record 49 of Set 5 | shache
# -------------------------
# Processing record 50 of Set 5 | tongren
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 6 | puerto del rosario
# -------------------------
# Processing record 2 of Set 6 | faanui
# -------------------------
# Processing record 3 of Set 6 | mollendo
# -------------------------
# Processing record 4 of Set 6 | ust-kuyga
# -------------------------
# Processing record 5 of Set 6 | potosi
# -------------------------
# Processing record 6 of Set 6 | gazimurskiy zavod
# -------------------------
# Processing record 7 of Set 6 | gushikawa
# -------------------------
# Processing record 8 of Set 6 | waingapu
# -------------------------
# Processing record 9 of Set 6 | dunedin
# -------------------------
# Processing record 10 of Set 6 | bolanos de calatrava
# -------------------------
# Processing record 11 of Set 6 | virden
# -------------------------
# Processing record 12 of Set 6 | itoman
# -------------------------
# Processing record 13 of Set 6 | hudson bay
# -------------------------
# Processing record 14 of Set 6 | terrace
# -------------------------
# Processing record 15 of Set 6 | buraydah
# -------------------------
# Processing record 16 of Set 6 | meulaboh
# -------------------------
# Processing record 17 of Set 6 | sudak
# -------------------------
# Processing record 18 of Set 6 | san patricio
# -------------------------
# Processing record 19 of Set 6 | aflu
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 20 of Set 6 | saint joseph
# -------------------------
# Processing record 21 of Set 6 | jumla
# -------------------------
# Processing record 22 of Set 6 | kabalo
# -------------------------
# Processing record 23 of Set 6 | san andres
# -------------------------
# Processing record 24 of Set 6 | klaksvik
# -------------------------
# Processing record 25 of Set 6 | mahebourg
# -------------------------
# Processing record 26 of Set 6 | dinsor
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 27 of Set 6 | tenerife
# -------------------------
# Processing record 28 of Set 6 | vardo
# -------------------------
# Processing record 29 of Set 6 | vawkavysk
# -------------------------
# Processing record 30 of Set 6 | shimoda
# -------------------------
# Processing record 31 of Set 6 | mareeba
# -------------------------
# Processing record 32 of Set 6 | los llanos de aridane
# -------------------------
# Processing record 33 of Set 6 | kalmunai
# -------------------------
# Processing record 34 of Set 6 | jiddah
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 35 of Set 6 | souillac
# -------------------------
# Processing record 36 of Set 6 | glendive
# -------------------------
# Processing record 37 of Set 6 | kiruna
# -------------------------
# Processing record 38 of Set 6 | victoria
# -------------------------
# Processing record 39 of Set 6 | talnakh
# -------------------------
# Processing record 40 of Set 6 | cidreira
# -------------------------
# Processing record 41 of Set 6 | kiyasovo
# -------------------------
# Processing record 42 of Set 6 | pevek
# -------------------------
# Processing record 43 of Set 6 | genhe
# -------------------------
# Processing record 44 of Set 6 | gat
# -------------------------
# Processing record 45 of Set 6 | honningsvag
# -------------------------
# Processing record 46 of Set 6 | ancud
# -------------------------
# Processing record 47 of Set 6 | walla walla
# -------------------------
# Processing record 48 of Set 6 | paamiut
# -------------------------
# Processing record 49 of Set 6 | batemans bay
# -------------------------
# Processing record 50 of Set 6 | tilichiki
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 7 | orzhytsya
# -------------------------
# Processing record 2 of Set 7 | phan thiet
# -------------------------
# Processing record 3 of Set 7 | the valley
# -------------------------
# Processing record 4 of Set 7 | puerto escondido
# -------------------------
# Processing record 5 of Set 7 | amarillo
# -------------------------
# Processing record 6 of Set 7 | kungurtug
# -------------------------
# Processing record 7 of Set 7 | clyde river
# -------------------------
# Processing record 8 of Set 7 | isla vista
# -------------------------
# Processing record 9 of Set 7 | zhaotong
# -------------------------
# Processing record 10 of Set 7 | saleaula
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 11 of Set 7 | nipawin
# -------------------------
# Processing record 12 of Set 7 | littleton
# -------------------------
# Processing record 13 of Set 7 | aktash
# -------------------------
# Processing record 14 of Set 7 | umm lajj
# -------------------------
# Processing record 15 of Set 7 | avera
# -------------------------
# Processing record 16 of Set 7 | bull savanna
# -------------------------
# Processing record 17 of Set 7 | axim
# -------------------------
# Processing record 18 of Set 7 | necochea
# -------------------------
# Processing record 19 of Set 7 | stelle
# -------------------------
# Processing record 20 of Set 7 | margate
# -------------------------
# Processing record 21 of Set 7 | sorong
# -------------------------
# Processing record 22 of Set 7 | itarema
# -------------------------
# Processing record 23 of Set 7 | kasempa
# -------------------------
# Processing record 24 of Set 7 | tiksi
# -------------------------
# Processing record 25 of Set 7 | asfi
# -------------------------
# Processing record 26 of Set 7 | marawi
# -------------------------
# Processing record 27 of Set 7 | fairbanks
# -------------------------
# Processing record 28 of Set 7 | yinchuan
# -------------------------
# Processing record 29 of Set 7 | bambous virieux
# -------------------------
# Processing record 30 of Set 7 | karanpura
# -------------------------
# Processing record 31 of Set 7 | sao filipe
# -------------------------
# Processing record 32 of Set 7 | temaraia
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 33 of Set 7 | ostrovnoy
# -------------------------
# Processing record 34 of Set 7 | pedernales
# -------------------------
# Processing record 35 of Set 7 | sakakah
# -------------------------
# Processing record 36 of Set 7 | loandjili
# -------------------------
# Processing record 37 of Set 7 | atikokan
# -------------------------
# Processing record 38 of Set 7 | mende
# -------------------------
# Processing record 39 of Set 7 | angoche
# -------------------------
# Processing record 40 of Set 7 | maghama
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 41 of Set 7 | amnat charoen
# -------------------------
# Processing record 42 of Set 7 | vanimo
# -------------------------
# Processing record 43 of Set 7 | bilma
# -------------------------
# Processing record 44 of Set 7 | kenai
# -------------------------
# Processing record 45 of Set 7 | lorengau
# -------------------------
# Processing record 46 of Set 7 | saint-louis
# -------------------------
# Processing record 47 of Set 7 | alofi
# -------------------------
# Processing record 48 of Set 7 | wazzan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 49 of Set 7 | alta floresta
# -------------------------
# Processing record 50 of Set 7 | sorvag
# -------------------------
# City not found, skipping...
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 8 | otradnoye
# -------------------------
# Processing record 2 of Set 8 | barra patuca
# -------------------------
# Processing record 3 of Set 8 | hearst
# -------------------------
# Processing record 4 of Set 8 | kaitangata
# -------------------------
# Processing record 5 of Set 8 | portland
# -------------------------
# Processing record 6 of Set 8 | guerrero negro
# -------------------------
# Processing record 7 of Set 8 | pangnirtung
# -------------------------
# Processing record 8 of Set 8 | banjar
# -------------------------
# Processing record 9 of Set 8 | ust-kamchatsk
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 10 of Set 8 | ruatoria
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 11 of Set 8 | namatanai
# -------------------------
# Processing record 12 of Set 8 | nsanje
# -------------------------
# Processing record 13 of Set 8 | zhigalovo
# -------------------------
# Processing record 14 of Set 8 | jaque
# -------------------------
# Processing record 15 of Set 8 | oranjemund
# -------------------------
# Processing record 16 of Set 8 | bonanza
# -------------------------
# Processing record 17 of Set 8 | comlosu mare
# -------------------------
# Processing record 18 of Set 8 | baloda bazar
# -------------------------
# Processing record 19 of Set 8 | santa fe
# -------------------------
# Processing record 20 of Set 8 | merrill
# -------------------------
# Processing record 21 of Set 8 | bossembele
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 22 of Set 8 | nacala
# -------------------------
# Processing record 23 of Set 8 | karang tengah
# -------------------------
# Processing record 24 of Set 8 | pathein
# -------------------------
# Processing record 25 of Set 8 | kisangani
# -------------------------
# Processing record 26 of Set 8 | adrar
# -------------------------
# Processing record 27 of Set 8 | kosh-agach
# -------------------------
# Processing record 28 of Set 8 | yar-sale
# -------------------------
# Processing record 29 of Set 8 | porbandar
# -------------------------
# Processing record 30 of Set 8 | skagastrond
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 31 of Set 8 | lotofaga
# -------------------------
# Processing record 32 of Set 8 | guadalupe y calvo
# -------------------------
# Processing record 33 of Set 8 | paita
# -------------------------
# Processing record 34 of Set 8 | vestmannaeyjar
# -------------------------
# Processing record 35 of Set 8 | nouadhibou
# -------------------------
# Processing record 36 of Set 8 | lagoa
# -------------------------
# Processing record 37 of Set 8 | surman
# -------------------------
# Processing record 38 of Set 8 | anshan
# -------------------------
# Processing record 39 of Set 8 | sahy
# -------------------------
# Processing record 40 of Set 8 | pochutla
# -------------------------
# Processing record 41 of Set 8 | aksu
# -------------------------
# Processing record 42 of Set 8 | sayyan
# -------------------------
# Processing record 43 of Set 8 | alpena
# -------------------------
# Processing record 44 of Set 8 | bunda
# -------------------------
# Processing record 45 of Set 8 | wanning
# -------------------------
# Processing record 46 of Set 8 | elban
# -------------------------
# Processing record 47 of Set 8 | talagang
# -------------------------
# Processing record 48 of Set 8 | havre-saint-pierre
# -------------------------
# Processing record 49 of Set 8 | cayenne
# -------------------------
# Processing record 50 of Set 8 | dinguiraye
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 9 | omsk
# -------------------------
# Processing record 2 of Set 9 | gunnedah
# -------------------------
# Processing record 3 of Set 9 | saint-joseph
# -------------------------
# Processing record 4 of Set 9 | kegayli
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 5 of Set 9 | nizwa
# -------------------------
# Processing record 6 of Set 9 | zhigansk
# -------------------------
# Processing record 7 of Set 9 | nanakuli
# -------------------------
# Processing record 8 of Set 9 | bulungu
# -------------------------
# Processing record 9 of Set 9 | preobrazheniye
# -------------------------
# Processing record 10 of Set 9 | lumding
# -------------------------
# Processing record 11 of Set 9 | lujan
# -------------------------
# Processing record 12 of Set 9 | sao raimundo das mangabeiras
# -------------------------
# Processing record 13 of Set 9 | alice springs
# -------------------------
# Processing record 14 of Set 9 | laureles
# -------------------------
# Processing record 15 of Set 9 | hambantota
# -------------------------
# Processing record 16 of Set 9 | coahuayana
# -------------------------
# Processing record 17 of Set 9 | inderborskiy
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 18 of Set 9 | taldan
# -------------------------
# Processing record 19 of Set 9 | dubrovytsya
# -------------------------
# Processing record 20 of Set 9 | egvekinot
# -------------------------
# Processing record 21 of Set 9 | helsingborg
# -------------------------
# Processing record 22 of Set 9 | at-bashi
# -------------------------
# Processing record 23 of Set 9 | zheleznodorozhnyy
# -------------------------
# Processing record 24 of Set 9 | talawdi
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 25 of Set 9 | churapcha
# -------------------------
# Processing record 26 of Set 9 | bacolod
# -------------------------
# Processing record 27 of Set 9 | ardesen
# -------------------------
# Processing record 28 of Set 9 | san cristobal
# -------------------------
# Processing record 29 of Set 9 | tarbagatay
# -------------------------
# Processing record 30 of Set 9 | brewster
# -------------------------
# Processing record 31 of Set 9 | lata
# -------------------------
# Processing record 32 of Set 9 | port lincoln
# -------------------------
# Processing record 33 of Set 9 | abasar
# -------------------------
# Processing record 34 of Set 9 | kaohsiung
# -------------------------
# Processing record 35 of Set 9 | madimba
# -------------------------
# Processing record 36 of Set 9 | paramonga
# -------------------------
# Processing record 37 of Set 9 | olinda
# -------------------------
# Processing record 38 of Set 9 | outjo
# -------------------------
# Processing record 39 of Set 9 | tarko-sale
# -------------------------
# Processing record 40 of Set 9 | hamilton
# -------------------------
# Processing record 41 of Set 9 | matagami
# -------------------------
# Processing record 42 of Set 9 | soanierana ivongo
# -------------------------
# Processing record 43 of Set 9 | sciacca
# -------------------------
# Processing record 44 of Set 9 | serov
# -------------------------
# Processing record 45 of Set 9 | samarkand
# -------------------------
# Processing record 46 of Set 9 | bandarbeyla
# -------------------------
# Processing record 47 of Set 9 | querfurt
# -------------------------
# Processing record 48 of Set 9 | laguna
# -------------------------
# Processing record 49 of Set 9 | mercedes
# -------------------------
# Processing record 50 of Set 9 | monte patria
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 10 | fernley
# -------------------------
# Processing record 2 of Set 10 | boa vista
# -------------------------
# Processing record 3 of Set 10 | havelock
# -------------------------
# Processing record 4 of Set 10 | kayes
# -------------------------
# Processing record 5 of Set 10 | botou
# -------------------------
# Processing record 6 of Set 10 | haines junction
# -------------------------
# Processing record 7 of Set 10 | saint george
# -------------------------
# Processing record 8 of Set 10 | khakhea
# -------------------------
# Processing record 9 of Set 10 | abdanan
# -------------------------
# Processing record 10 of Set 10 | fuente de oro
# -------------------------
# Processing record 11 of Set 10 | lolua
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 12 of Set 10 | teguise
# -------------------------
# Processing record 13 of Set 10 | dunda
# -------------------------
# Processing record 14 of Set 10 | san jeronimo
# -------------------------
# Processing record 15 of Set 10 | palabuhanratu
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 16 of Set 10 | christchurch
# -------------------------
# Processing record 17 of Set 10 | corbita
# -------------------------
# Processing record 18 of Set 10 | havoysund
# -------------------------
# Processing record 19 of Set 10 | vreed en hoop
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 20 of Set 10 | phuket
# -------------------------
# Processing record 21 of Set 10 | san jose
# -------------------------
# Processing record 22 of Set 10 | cheuskiny
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 23 of Set 10 | kargil
# -------------------------
# Processing record 24 of Set 10 | one hundred mile house
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 25 of Set 10 | namibe
# -------------------------
# Processing record 26 of Set 10 | kropotkin
# -------------------------
# Processing record 27 of Set 10 | qinhuangdao
# -------------------------
# Processing record 28 of Set 10 | tiznit
# -------------------------
# Processing record 29 of Set 10 | west bay
# -------------------------
# Processing record 30 of Set 10 | suntar
# -------------------------
# Processing record 31 of Set 10 | tumarbong
# -------------------------
# Processing record 32 of Set 10 | viligili
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 33 of Set 10 | viedma
# -------------------------
# Processing record 34 of Set 10 | karamken
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 35 of Set 10 | dowa
# -------------------------
# Processing record 36 of Set 10 | avallon
# -------------------------
# Processing record 37 of Set 10 | port hedland
# -------------------------
# Processing record 38 of Set 10 | sabang
# -------------------------
# Processing record 39 of Set 10 | trenggalek
# -------------------------
# Processing record 40 of Set 10 | jalu
# -------------------------
# Processing record 41 of Set 10 | abalak
# -------------------------
# Processing record 42 of Set 10 | corning
# -------------------------
# Processing record 43 of Set 10 | tuy hoa
# -------------------------
# Processing record 44 of Set 10 | paka
# -------------------------
# Processing record 45 of Set 10 | bendigo
# -------------------------
# Processing record 46 of Set 10 | paracuru
# -------------------------
# Processing record 47 of Set 10 | aban
# -------------------------
# Processing record 48 of Set 10 | yuzhno-yeniseyskiy
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 49 of Set 10 | severo-kurilsk
# -------------------------
# Processing record 50 of Set 10 | kushmurun
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 11 | oranjestad
# -------------------------
# Processing record 2 of Set 11 | boyolangu
# -------------------------
# Processing record 3 of Set 11 | cleveland
# -------------------------
# Processing record 4 of Set 11 | oussouye
# -------------------------
# Processing record 5 of Set 11 | solnechnyy
# -------------------------
# Processing record 6 of Set 11 | wad rawah
# -------------------------
# Processing record 7 of Set 11 | sistranda
# -------------------------
# Processing record 8 of Set 11 | znamenskoye
# -------------------------
# Processing record 9 of Set 11 | lhuntshi
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 10 of Set 11 | fare
# -------------------------
# Processing record 11 of Set 11 | asosa
# -------------------------
# Processing record 12 of Set 11 | worpswede
# -------------------------
# Processing record 13 of Set 11 | sembe
# -------------------------
# Processing record 14 of Set 11 | tongzi
# -------------------------
# Processing record 15 of Set 11 | koulikoro
# -------------------------
# Processing record 16 of Set 11 | makubetsu
# -------------------------
# Processing record 17 of Set 11 | isla mujeres
# -------------------------
# Processing record 18 of Set 11 | juneau
# -------------------------
# Processing record 19 of Set 11 | corrente
# -------------------------
# Processing record 20 of Set 11 | hanyang
# -------------------------
# Processing record 21 of Set 11 | vung tau
# -------------------------
# Processing record 22 of Set 11 | sept-iles
# -------------------------
# Processing record 23 of Set 11 | atambua
# -------------------------
# Processing record 24 of Set 11 | soe
# -------------------------
# Processing record 25 of Set 11 | sechura
# -------------------------
# Processing record 26 of Set 11 | andros
# -------------------------
# Processing record 27 of Set 11 | ponta pora
# -------------------------
# Processing record 28 of Set 11 | sinnamary
# -------------------------
# Processing record 29 of Set 11 | cherskiy
# -------------------------
# Processing record 30 of Set 11 | barawe
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 31 of Set 11 | hongan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 32 of Set 11 | kayfan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 33 of Set 11 | mweka
# -------------------------
# Processing record 34 of Set 11 | chihuahua
# -------------------------
# Processing record 35 of Set 11 | maloshuyka
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 36 of Set 11 | todos santos
# -------------------------
# Processing record 37 of Set 11 | belgrade
# -------------------------
# Processing record 38 of Set 11 | faya
# -------------------------
# Processing record 39 of Set 11 | jiangyou
# -------------------------
# Processing record 40 of Set 11 | almansa
# -------------------------
# Processing record 41 of Set 11 | ornskoldsvik
# -------------------------
# Processing record 42 of Set 11 | caceres
# -------------------------
# Processing record 43 of Set 11 | katherine
# -------------------------
# Processing record 44 of Set 11 | tinskoy
# -------------------------
# Processing record 45 of Set 11 | te anau
# -------------------------
# Processing record 46 of Set 11 | ayagoz
# -------------------------
# Processing record 47 of Set 11 | samalaeulu
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 48 of Set 11 | durango
# -------------------------
# Processing record 49 of Set 11 | calabozo
# -------------------------
# Processing record 50 of Set 11 | barcelona
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 12 | marystown
# -------------------------
# Processing record 2 of Set 12 | tabarqah
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 3 of Set 12 | namie
# -------------------------
# Processing record 4 of Set 12 | killam
# -------------------------
# Processing record 5 of Set 12 | lahaina
# -------------------------
# Processing record 6 of Set 12 | rungata
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 7 of Set 12 | neepawa
# -------------------------
# Processing record 8 of Set 12 | gravelbourg
# -------------------------
# Processing record 9 of Set 12 | pacific grove
# -------------------------
# Processing record 10 of Set 12 | noumea
# -------------------------
# Processing record 11 of Set 12 | vaitape
# -------------------------
# Processing record 12 of Set 12 | ramshir
# -------------------------
# Processing record 13 of Set 12 | sioux lookout
# -------------------------
# Processing record 14 of Set 12 | san ignacio
# -------------------------
# Processing record 15 of Set 12 | saryshagan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 16 of Set 12 | pundaguitan
# -------------------------
# Processing record 17 of Set 12 | hobyo
# -------------------------
# Processing record 18 of Set 12 | voznesenye
# -------------------------
# Processing record 19 of Set 12 | warqla
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 20 of Set 12 | tignere
# -------------------------
# Processing record 21 of Set 12 | santa cruz
# -------------------------
# Processing record 22 of Set 12 | tabiauea
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 23 of Set 12 | tumut
# -------------------------
# Processing record 24 of Set 12 | caraballeda
# -------------------------
# Processing record 25 of Set 12 | mahibadhoo
# -------------------------
# Processing record 26 of Set 12 | xingyi
# -------------------------
# Processing record 27 of Set 12 | carutapera
# -------------------------
# Processing record 28 of Set 12 | belawan
# -------------------------
# Processing record 29 of Set 12 | virginia beach
# -------------------------
# Processing record 30 of Set 12 | nam som
# -------------------------
# Processing record 31 of Set 12 | saint-leu
# -------------------------
# Processing record 32 of Set 12 | ondorhaan
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 33 of Set 12 | honiara
# -------------------------
# Processing record 34 of Set 12 | hunza
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 35 of Set 12 | turan
# -------------------------
# Processing record 36 of Set 12 | fukue
# -------------------------
# Processing record 37 of Set 12 | lethem
# -------------------------
# Processing record 38 of Set 12 | roald
# -------------------------
# Processing record 39 of Set 12 | sola
# -------------------------
# Processing record 40 of Set 12 | cockburn town
# -------------------------
# Processing record 41 of Set 12 | teseney
# -------------------------
# Processing record 42 of Set 12 | imbituba
# -------------------------
# Processing record 43 of Set 12 | khormuj
# -------------------------
# City not found, skipping...
# -------------------------
# Processing record 44 of Set 12 | gillingham
# -------------------------
# Processing record 45 of Set 12 | celestun
# -------------------------
# Processing record 46 of Set 12 | yerbogachen
# -------------------------
# Processing record 47 of Set 12 | hirara
# -------------------------
# Processing record 48 of Set 12 | saiha
# -------------------------
# Processing record 49 of Set 12 | ballia
# -------------------------
# Processing record 50 of Set 12 | tutoia
# -------------------------
# 50 results found, waiting for API to refresh
# Processing record 1 of Set 13 | chancay
# -------------------------
# Processing record 2 of Set 13 | tomatlan
# -------------------------
# Data retrieval complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_dict = {
    'City':weather_city,
    'Cloudiness':cloudiness,
    'Country':country,
    'Date':date,
    'Humidity':humidity,
    'Lat':lat,
    'Lng':lng,
    'Max Temp':max_temp,
    'Wind Speed':wind
}
cities_weather = pd.DataFrame(cities_dict)
cities_weather.head()
# cities_weather.info()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Usinsk          92      RU  1579894582        98  65.99   57.53
# 1        Upernavik          58      GL  1579894203        90  72.79  -56.15
# 2  Severo-Kuril'sk          80      RU  1579894016        87  50.68  156.12
# 3            Vardo          75      NO  1579894494        63  70.37   31.11
# 4          Salalah           0      OM  1579894165        73  17.02   54.09
#
#    Max Temp  Wind Speed
# 0     -2.74        6.06
# 1    -13.90        5.53
# 2     14.31       22.82
# 3     26.60       13.87
# 4     77.00        2.24

# %%
cities_weather.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig1, ax1 = plt.subplots()
cities_weather.plot(kind='scatter',x='Lat',y='Max Temp', ax=ax1,edgecolors='black',grid=True)
ax1.grid(linestyle='-',linewidth='0.5')
plt.title('City Latitude vs Max Temperature (1/24/2019)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()
plt.savefig("../output_data/fig1-Lat_Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig2, ax2 = plt.subplots()
cities_weather.plot(kind='scatter',x='Lat',y='Humidity', ax=ax2,edgecolors='black',grid=True)
ax2.grid(linestyle='-',linewidth='0.5')
plt.title('City Latitude vs Humidity (1/24/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
plt.savefig("../output_data/fig2-Lat_Hum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig3, ax3 = plt.subplots()
cities_weather.plot(kind='scatter',x='Lat',y='Cloudiness', ax=ax3,edgecolors='black',grid=True)
ax3.grid(linestyle='-',linewidth='0.5')
plt.title('City Latitude vs Cloudiness (1/24/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
plt.savefig("../output_data/fig3-Lat_Cloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig4, ax4 = plt.subplots()
cities_weather.plot(kind='scatter',x='Lat',y='Wind Speed', ax=ax4,edgecolors='black',grid=True)
ax4.grid(linestyle='-',linewidth='0.5')
plt.title('City Latitude vs Wind Speed (1/24/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
plt.savefig("../output_data/fig4-Lat_Wind.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# n_slope,n_int,n_r,n_p,n_std_err = linregress(xaxis,yaxis)
# n_fit = n_slope*xaxis+n_int
# s_slope,s_int,s_r,s_p,s_std_err = linregress(xaxis,yaxis)
# s_fit = s_slope*xaxis+s_int

# %%
# Create Northern and Southern Hemisphere DataFrames
north = cities_weather[cities_weather.Lat >0]
south = cities_weather[cities_weather.Lat <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xaxis = north['Lat']
yaxis = north['Max Temp']
n_slope,n_int,n_r,n_p,n_std_err = linregress(xaxis,yaxis)
n_fit = n_slope*xaxis+n_int
r_sq = round(n_r**2,3)
line_eq='y = '+str(round(n_slope,2))+'x + '+str(round(n_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,n_fit,'--',color='red')
plt.annotate(line_eq,(6,-20),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.704

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xaxis = south['Lat']
yaxis = south['Max Temp']
s_slope,s_int,s_r,s_p,s_std_err = linregress(xaxis,yaxis)
s_fit = s_slope*xaxis+s_int
r_sq = round(s_r**2,3)
line_eq='y = '+str(round(s_slope,2))+'x + '+str(round(s_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,s_fit,'--',color='red')
plt.annotate(line_eq,(-40,50),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.181

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xaxis = north['Lat']
yaxis = north['Humidity']
n_slope,n_int,n_r,n_p,n_std_err = linregress(xaxis,yaxis)
n_fit = n_slope*xaxis+n_int
r_sq = round(n_r**2,3)
line_eq='y = '+str(round(n_slope,2))+'x + '+str(round(n_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,n_fit,'--',color='red')
plt.annotate(line_eq,(45,30),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.203

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xaxis = south['Lat']
yaxis = south['Humidity']
s_slope,s_int,s_r,s_p,s_std_err = linregress(xaxis,yaxis)
s_fit = s_slope*xaxis+s_int
r_sq = round(s_r**2,3)
line_eq='y = '+str(round(s_slope,2))+'x + '+str(round(s_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,s_fit,'--',color='red')
plt.annotate(line_eq,(-25,20),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.048

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xaxis = north['Lat']
yaxis = north['Cloudiness']
n_slope,n_int,n_r,n_p,n_std_err = linregress(xaxis,yaxis)
n_fit = n_slope*xaxis+n_int
r_sq = round(n_r**2,3)
line_eq='y = '+str(round(n_slope,2))+'x + '+str(round(n_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,n_fit,'--',color='red')
plt.annotate(line_eq,(45,30),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.029

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xaxis = south['Lat']
yaxis = south['Cloudiness']
s_slope,s_int,s_r,s_p,s_std_err = linregress(xaxis,yaxis)
s_fit = s_slope*xaxis+s_int
r_sq = round(s_r**2,3)
line_eq='y = '+str(round(s_slope,2))+'x + '+str(round(s_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,s_fit,'--',color='red')
plt.annotate(line_eq,(-50,30),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.012

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xaxis = north['Lat']
yaxis = north['Wind Speed']
n_slope,n_int,n_r,n_p,n_std_err = linregress(xaxis,yaxis)
n_fit = n_slope*xaxis+n_int
r_sq = round(n_r**2,3)
line_eq='y = '+str(round(n_slope,2))+'x + '+str(round(n_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,n_fit,'--',color='red')
plt.annotate(line_eq,(0,25),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.015

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xaxis = south['Lat']
yaxis = south['Wind Speed']
s_slope,s_int,s_r,s_p,s_std_err = linregress(xaxis,yaxis)
s_fit = s_slope*xaxis+s_int
r_sq = round(s_r**2,3)
line_eq='y = '+str(round(s_slope,2))+'x + '+str(round(s_int,2))
plt.scatter(xaxis,yaxis)
plt.plot(xaxis,s_fit,'--',color='red')
plt.annotate(line_eq,(-50,25),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f'The r-squared is: {r_sq}')
plt.show()
# Out:
# The r-squared is: 0.049
